# %%
from wbot import read
import numpy as np
import colorama
from auto_solve import auto_solve
    
    #load numpy array containing every possible wordle answer
plist=np.array(read.word_list('possible'))

    #load numpy array containing every allowed wordle guess 
glist=np.array(read.word_list('allowed'))

    #load pre-computed grid containing all tile combinations for each guess and possible answer word pair
tiles_grid=np.load('wbot/all_tiles.npz')['data']

    #load pre-computed unique tile patterns given the first word is 'salet'
sal_patterns=np.load('wbot/salet_patterns.npy')

    #load each of the precomputed best second guess words for each tile pattern, given the first word was 'salet'.
sal_guess=np.load('wbot/salet_guess.npy')

res=[]
for w in plist:   
    guess,count=auto_solve(w,tiles_grid,plist,glist,sal_patterns,sal_guess)
    res+=[count]
    print(guess,np.mean(res))
# Out:
# True Word: ABACK
#
# SALET
#
#
# BROND
#
#
# ABACK
#
# Total Guesses:  3
# aback 3.0
# True Word: ABASE
#
# SALET
#
#
# BRASH
#
#
# ABASE
#
# Total Guesses:  3
# abase 3.0
# True Word: ABATE
#
# SALET
#
#
# GRACE
#
#
# ABATE
#
# Total Guesses:  3
# abate 3.0
# True Word: ABBEY
#
# SALET
#
#
# UNRED
#
#
# ABBEY
#
# Total Guesses:  3
# abbey 3.0
# True Word: ABBOT
#
# SALET
#
#
# CRUDO
#
#
# ABBOT
#
# Total Guesses:  3
# abbot 3.0
# True Word: ABHOR
#
# SALET
#
#
# BROND
#
#
# ABHOR
#
# Total Guesses:  3
# abhor 3.0
# True Word: ABIDE
#
# SALET
#
#
# BEARD
#
#
# ABIDE
#
# Total Guesses:  3
# abide 3.0
# True Word: ABLED
#
# SALET
#
#
# ABLED
#
# Total Guesses:  2
# abled 2.875
# True Word: ABODE
#
# SALET
#
#
# BEARD
#
#
# ABIDE
#
#
# ABODE
#
# Total Guesses:  4
# abode 3.0
# True Word: ABORT
#
# SALET
#
#
# CRUDO
#
#
# ABORT
#
# Total Guesses:  3
# abort 3.0
# True Word: ABOUT
#
# SALET
#
#
# CRUDO
#
#
# ABOUT
#
# Total Guesses:  3
# about 3.0
# True Word: ABOVE
#
# SALET
#
#
# BEARD
#
#
# ABOVE
#
# Total Guesses:  3
# above 3.0
# True Word: ABUSE
#
# SALET
#
#
# BRASH
#
#
# ABUSE
#
# Total Guesses:  3
# abuse 3.0
# True Word: ABYSS
#
# SALET
#
#
# CRAGS
#
#
# ABYSS
#
# Total Guesses:  3
# abyss 3.0
# True Word: ACORN
#
# SALET
#
#
# BROND
#
#
# ACORN
#
# Total Guesses:  3
# acorn 3.0
# True Word: ACRID
#
# SALET
#
#
# BROND
#
#
# ACRID
#
# Total Guesses:  3
# acrid 3.0
# True Word: ACTOR
#
# SALET
#
#
# TRONC
#
#
# ACTOR
#
# Total Guesses:  3
# actor 3.0
# True Word: ACUTE
#
# SALET
#
#
# GRACE
#
#
# ACUTE
#
# Total Guesses:  3
# acute 3.0
# True Word: ADAGE
#
# SALET
#
#
# BEARD
#
#
# ADAGE
#
# Total Guesses:  3
# adage 3.0
# True Word: ADAPT
#
# SALET
#
#
# CRUDO
#
#
# ADAPT
#
# Total Guesses:  3
# adapt 3.0
# True Word: ADEPT
#
# SALET
#
#
# CRENA
#
#
# ADEPT
#
# Total Guesses:  3
# adept 3.0
# True Word: ADMIN
#
# SALET
#
#
# BROND
#
#
# ADMIN
#
# Total Guesses:  3
# admin 3.0
# True Word: ADMIT
#
# SALET
#
#
# CRUDO
#
#
# ADAPT
#
#
# ADMIT
#
# Total Guesses:  4
# admit 3.0434782608695654
# True Word: ADOBE
#
# SALET
#
#
# BEARD
#
#
# ABIDE
#
#
# ADOBE
#
# Total Guesses:  4
# adobe 3.0833333333333335
# True Word: ADOPT
#
# SALET
#
#
# CRUDO
#
#
# ADOPT
#
# Total Guesses:  3
# adopt 3.08
# True Word: ADORE
#
# SALET
#
#
# BEARD
#
#
# ADORE
#
# Total Guesses:  3
# adore 3.076923076923077
# True Word: ADORN
#
# SALET
#
#
# BROND
#
#
# ADORN
#
# Total Guesses:  3
# adorn 3.074074074074074
# True Word: ADULT
#
# SALET
#
#
# FUNGI
#
#
# ADULT
#
# Total Guesses:  3
# adult 3.0714285714285716
# True Word: AFFIX
#
# SALET
#
#
# BROND
#
#
# PLUCK
#
#
# AFFIX
#
# Total Guesses:  4
# affix 3.103448275862069
# True Word: AFIRE
#
# SALET
#
#
# BEARD
#
#
# AFIRE
#
# Total Guesses:  3
# afire 3.1
# True Word: AFOOT
#
# SALET
#
#
# CRUDO
#
#
# ABBOT
#
#
# AFOOT
#
# Total Guesses:  4
# afoot 3.129032258064516
# True Word: AFOUL
#
# SALET
#
#
# CORNI
#
#
# AFOUL
#
# Total Guesses:  3
# afoul 3.125
# True Word: AFTER
#
# SALET
#
#
# AFTER
#
# Total Guesses:  2
# after 3.090909090909091
# True Word: AGAIN
#
# SALET
#
#
# BROND
#
#
# CABIN
#
#
# AGAIN
#
# Total Guesses:  4
# again 3.1176470588235294
# True Word: AGAPE
#
# SALET
#
#
# BEARD
#
#
# KANGA
#
#
# AGAPE
#
# Total Guesses:  4
# agape 3.142857142857143
# True Word: AGATE
#
# SALET
#
#
# GRACE
#
#
# AGATE
#
# Total Guesses:  3
# agate 3.138888888888889
# True Word: AGENT
#
# SALET
#
#
# CRENA
#
#
# AGENT
#
# Total Guesses:  3
# agent 3.135135135135135
# True Word: AGILE
#
# SALET
#
#
# GLARE
#
#
# AGILE
#
# Total Guesses:  3
# agile 3.1315789473684212
# True Word: AGING
#
# SALET
#
#
# BROND
#
#
# AGING
#
# Total Guesses:  3
# aging 3.128205128205128
# True Word: AGLOW
#
# SALET
#
#
# ALLAY
#
#
# AGLOW
#
# Total Guesses:  3
# aglow 3.125
# True Word: AGONY
#
# SALET
#
#
# BROND
#
#
# AGONY
#
# Total Guesses:  3
# agony 3.1219512195121952
# True Word: AGREE
#
# SALET
#
#
# UNRED
#
#
# AGREE
#
# Total Guesses:  3
# agree 3.119047619047619
# True Word: AHEAD
#
# SALET
#
#
# BEARD
#
#
# AHEAD
#
# Total Guesses:  3
# ahead 3.116279069767442
# True Word: AIDER
#
# SALET
#
#
# UNRED
#
#
# AIDER
#
# Total Guesses:  3
# aider 3.1136363636363638
# True Word: AISLE
#
# SALET
#
#
# AISLE
#
# Total Guesses:  2
# aisle 3.088888888888889
# True Word: ALARM
#
# SALET
#
#
# CORNI
# BRAWL
#
#
# ALARM
#
# Total Guesses:  4
# alarm 3.108695652173913
# True Word: ALBUM
#
# SALET
#
#
# CORNI
#
#
# BUPPY
#
#
# ALBUM
#
# Total Guesses:  4
# album 3.127659574468085
# True Word: ALERT
#
# SALET
#
#
# RECAP
#
#
# ALERT
#
# Total Guesses:  3
# alert 3.125
# True Word: ALGAE
#
# SALET
#
#
# GLARE
#
#
# ALGAE
#
# Total Guesses:  3
# algae 3.122448979591837
# True Word: ALIBI
#
# SALET
#
#
# CORNI
#
#
# ALIBI
#
# Total Guesses:  3
# alibi 3.12
# True Word: ALIEN
#
# SALET
#
#
# ALIEN
#
# Total Guesses:  2
# alien 3.0980392156862746
# True Word: ALIGN
#
# SALET
#
#
# CORNI
#
#
# ALIGN
#
# Total Guesses:  3
# align 3.0961538461538463
# True Word: ALIKE
#
# SALET
#
#
# GLARE
#
#
# ALIKE
#
# Total Guesses:  3
# alike 3.0943396226415096
# True Word: ALIVE
#
# SALET
#
#
# GLARE
#
#
# ALIKE
#
#
# ALIVE
#
# Total Guesses:  4
# alive 3.111111111111111
# True Word: ALLAY
#
# SALET
#
#
# ALLAY
#
# Total Guesses:  2
# allay 3.090909090909091
# True Word: ALLEY
#
# SALET
#
#
# ABLED
#
#
# ALLEY
#
# Total Guesses:  3
# alley 3.0892857142857144
# True Word: ALLOT
#
# SALET
#
#
# ALLOT
#
# Total Guesses:  2
# allot 3.0701754385964914
# True Word: ALLOW
#
# SALET
#
#
# ALLAY
#
#
# ALLOW
#
# Total Guesses:  3
# allow 3.0689655172413794
# True Word: ALLOY
#
# SALET
#
#
# ALLAY
#
#
# ALLOY
#
# Total Guesses:  3
# alloy 3.0677966101694913
# True Word: ALOFT
#
# SALET
#
#
# FUNGI
#
#
# ALOFT
#
# Total Guesses:  3
# aloft 3.066666666666667
# True Word: ALONE
#
# SALET
#
#
# GLARE
#
#
# ALIKE
#
#
# ALONE
#
# Total Guesses:  4
# alone 3.081967213114754
# True Word: ALONG
#
# SALET
#
#
# CORNI
#
#
# ALONG
#
# Total Guesses:  3
# along 3.0806451612903225
# True Word: ALOOF
#
# SALET
#
#
# CORNI
#
#
# AFOUL
#
#
# ALOOF
#
# Total Guesses:  4
# aloof 3.0952380952380953
# True Word: ALOUD
#
# SALET
#
#
# CORNI
#
#
# AFOUL
#
#
# ALOUD
#
# Total Guesses:  4
# aloud 3.109375
# True Word: ALPHA
#
# SALET
#
#
# CORNI
#
#
# BUPPY
#
#
# ALPHA
#
# Total Guesses:  4
# alpha 3.123076923076923
# True Word: ALTAR
#
# SALET
#
#
# OTTAR
#
#
# ALTAR
#
# Total Guesses:  3
# altar 3.121212121212121
# True Word: ALTER
#
# SALET
#
#
# ALTER
#
# Total Guesses:  2
# alter 3.1044776119402986
# True Word: AMASS
#
# SALET
#
#
# CRAGS
#
#
# AMASS
#
# Total Guesses:  3
# amass 3.1029411764705883
# True Word: AMAZE
#
# SALET
#
#
# BEARD
#
#
# KANGA
#
#
# AMAZE
#
# Total Guesses:  4
# amaze 3.1159420289855073
# True Word: AMBER
#
# SALET
#
#
# UNRED
#
#
# AMBER
#
# Total Guesses:  3
# amber 3.1142857142857143
# True Word: AMBLE
#
# SALET
#
#
# GLARE
#
#
# AMPLE
#
#
# AMBLE
#
# Total Guesses:  4
# amble 3.1267605633802815
# True Word: AMEND
#
# SALET
#
#
# BEARD
#
#
# AHEAD
#
#
# AMEND
#
# Total Guesses:  4
# amend 3.138888888888889
# True Word: AMISS
#
# SALET
#
#
# CRAGS
#
#
# ABYSS
#
#
# AMISS
#
# Total Guesses:  4
# amiss 3.1506849315068495
# True Word: AMITY
#
# SALET
#
#
# TRONC
#
#
# AMITY
#
# Total Guesses:  3
# amity 3.1486486486486487
# True Word: AMONG
#
# SALET
#
#
# BROND
#
#
# AGONY
#
#
# AMONG
#
# Total Guesses:  4
# among 3.16
# True Word: AMPLE
#
# SALET
#
#
# GLARE
#
#
# AMPLE
#
# Total Guesses:  3
# ample 3.1578947368421053
# True Word: AMPLY
#
# SALET
#
#
# CORNI
#
#
# BUPPY
#
#
# AMPLY
#
# Total Guesses:  4
# amply 3.168831168831169
# True Word: AMUSE
#
# SALET
#
#
# BRASH
#
#
# AMUSE
#
# Total Guesses:  3
# amuse 3.1666666666666665
# True Word: ANGEL
#
# SALET
#
#
# ALIEN
#
#
# ANGEL
#
# Total Guesses:  3
# angel 3.1645569620253164
# True Word: ANGER
#
# SALET
#
#
# UNRED
#
#
# ANGER
#
# Total Guesses:  3
# anger 3.1625
# True Word: ANGLE
#
# SALET
#
#
# GLARE
#
#
# AGILE
#
#
# ANGLE
#
# Total Guesses:  4
# angle 3.1728395061728394
# True Word: ANGRY
#
# SALET
#
#
# BROND
#
#
# ANGRY
#
# Total Guesses:  3
# angry 3.1707317073170733
# True Word: ANGST
#
# SALET
#
#
# BRACK
#
#
# ANGST
#
# Total Guesses:  3
# angst 3.1686746987951806
# True Word: ANIME
#
# SALET
#
#
# BEARD
#
#
# GROMA
#
#
# ANIME
#
# Total Guesses:  4
# anime 3.1785714285714284
# True Word: ANKLE
#
# SALET
#
#
# GLARE
#
#
# AMPLE
#
#
# ANKLE
#
# Total Guesses:  4
# ankle 3.1882352941176473
# True Word: ANNEX
#
# SALET
#
#
# UNRED
#
#
# ANNEX
#
# Total Guesses:  3
# annex 3.186046511627907
# True Word: ANNOY
#
# SALET
#
#
# BROND
#
#
# ANNOY
#
# Total Guesses:  3
# annoy 3.1839080459770117
# True Word: ANNUL
#
# SALET
#
#
# CORNI
# ANNUL
#
# Total Guesses:  3
# annul 3.1818181818181817
# True Word: ANODE
#
# SALET
#
#
# BEARD
#
#
# ANODE
#
# Total Guesses:  3
# anode 3.1797752808988764
# True Word: ANTIC
#
# SALET
#
#
# TRONC
#
#
# ANTIC
#
# Total Guesses:  3
# antic 3.1777777777777776
# True Word: ANVIL
#
# SALET
#
#
# CORNI
#
#
# ALIGN
#
#
# ANVIL
#
# Total Guesses:  4
# anvil 3.1868131868131866
# True Word: AORTA
#
# SALET
#
#
# TRONC
#
#
# AORTA
#
# Total Guesses:  3
# aorta 3.1847826086956523
# True Word: APART
#
# SALET
#
#
# CRUDO
#
#
# APART
#
# Total Guesses:  3
# apart 3.182795698924731
# True Word: APHID
#
# SALET
#
#
# BROND
#
#
# APHID
#
# Total Guesses:  3
# aphid 3.1808510638297873
# True Word: APING
#
# SALET
#
#
# BROND
#
#
# AGING
#
#
# APING
#
# Total Guesses:  4
# aping 3.1894736842105265
# True Word: APNEA
#
# SALET
#
#
# UNRED
#
#
# APNEA
#
# Total Guesses:  3
# apnea 3.1875
# True Word: APPLE
#
# SALET
#
#
# GLARE
#
#
# AMPLE
#
#
# APPLE
#
# Total Guesses:  4
# apple 3.195876288659794
# True Word: APPLY
#
# SALET
#
#
# CORNI
#
#
# BUPPY
#
#
# APPLY
#
# Total Guesses:  4
# apply 3.204081632653061
# True Word: APRON
#
# SALET
#
#
# BROND
#
#
# APRON
#
# Total Guesses:  3
# apron 3.202020202020202
# True Word: APTLY
#
# SALET
#
#
# OTTAR
#
#
# APTLY
#
# Total Guesses:  3
# aptly 3.2
# True Word: ARBOR
#
# SALET
#
#
# BROND
#
#
# ARBOR
#
# Total Guesses:  3
# arbor 3.198019801980198
# True Word: ARDOR
#
# SALET
#
#
# BROND
#
#
# ARDOR
#
# Total Guesses:  3
# ardor 3.196078431372549
# True Word: ARENA
#
# SALET
#
#
# BEARD
#
#
# WACKE
#
#
# ARENA
#
# Total Guesses:  4
# arena 3.203883495145631
# True Word: ARGUE
#
# SALET
#
#
# BEARD
#
#
# WACKE
#
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_10130/1360836584.py", line 23, in <cell line: 22>
#     guess,count=auto_solve(w,tiles_grid,plist,glist,sal_patterns,sal_guess)
#   File "/data/bmb41/WordleBot/auto_solve.py", line 68, in auto_solve
#   File "/data/bmb41/WordleBot/wbot/solve_c.py", line 80, in info_grid
#     un_pat=np.unique(tgrid[i,:,:],axis=0)
#   File "<__array_function__ internals>", line 180, in unique
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/numpy/lib/arraysetops.py", line 319, in unique
#     output = (reshape_uniq(output[0]),) + output[1:]
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/numpy/lib/arraysetops.py", line 314, in reshape_uniq
#     uniq = np.moveaxis(uniq, 0, axis)
#   File "<__array_function__ internals>", line 180, in moveaxis
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/numpy/core/numeric.py", line 1466, in moveaxis
#     source = normalize_axis_tuple(source, a.ndim, 'source')
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/numpy/core/numeric.py", line 1347, in normalize_axis_tuple
#     def normalize_axis_tuple(axis, ndim, argname=None, allow_duplicate=False):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 1993, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/home/bmb41/.conda/envs/basic/lib/python3.10/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
